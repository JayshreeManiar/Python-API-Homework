# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy
url = "https://api.openweathermap.org/data/2.5/weather?&APPID="+ api_key

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
#print(https://api.openweathermap.org/data/2.5/weather?appid=169614e34427afdb73cdb18162b42982&q=port blair)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 610

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#for city in cities:
   # query_url+format(cities)
   # print("http://api.openweathermap.org?appid=169614e34427afdb73cdb18162b42982&q={}".format(city))

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []
record = 1
for city in cities:
    try:
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        city_record=response["name"]
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        
        print(f"Processing Record {record} | {city_record}")
        record=record+1
    except:        
        print(f"City not found. Skipping")
    continue
# Out:
# Processing Record 1 | Punta Arenas
# Processing Record 2 | Saint-Philippe
# Processing Record 3 | Ribeira Grande
# Processing Record 4 | Bredasdorp
# Processing Record 5 | Bluff
# Processing Record 6 | Port Elizabeth
# Processing Record 7 | Rikitea
# Processing Record 8 | Tuktoyaktuk
# Processing Record 9 | Ushuaia
# Processing Record 10 | Deer Lake
# Processing Record 11 | Nouadhibou
# Processing Record 12 | Kalulushi
# City not found. Skipping
# Processing Record 13 | Yellowknife
# Processing Record 14 | Port Hedland
# Processing Record 15 | Banfora
# Processing Record 16 | Cherskiy
# Processing Record 17 | Bethel
# Processing Record 18 | Gisborne
# Processing Record 19 | Arraial do Cabo
# Processing Record 20 | Hermanus
# Processing Record 21 | Beira
# Processing Record 22 | Sangar
# Processing Record 23 | Tura
# Processing Record 24 | Cambridge
# City not found. Skipping
# Processing Record 25 | Vaini
# Processing Record 26 | Severo-Kurilsk
# Processing Record 27 | Jamestown
# Processing Record 28 | Luanda
# Processing Record 29 | Nikolskoye
# Processing Record 30 | Fuente de Oro
# Processing Record 31 | Coquimbo
# Processing Record 32 | Tatvan
# Processing Record 33 | Salinas
# Processing Record 34 | Show Low
# Processing Record 35 | Minervino Murge
# Processing Record 36 | Dunda
# Processing Record 37 | Bukama
# Processing Record 38 | San Cristobal
# Processing Record 39 | Alta Floresta
# City not found. Skipping
# Processing Record 40 | Angicos
# Processing Record 41 | Najran
# Processing Record 42 | Saldanha
# Processing Record 43 | Puerto Ayora
# Processing Record 44 | Progreso
# Processing Record 45 | Saskylakh
# Processing Record 46 | Namibe
# Processing Record 47 | Umm Kaddadah
# Processing Record 48 | Chokurdakh
# Processing Record 49 | San Quintin
# Processing Record 50 | Wanning
# Processing Record 51 | Meulaboh
# Processing Record 52 | Thompson
# Processing Record 53 | Nazca
# Processing Record 54 | Albany
# Processing Record 55 | Saint-Alexandre
# Processing Record 56 | Viedma
# Processing Record 57 | Laguna
# Processing Record 58 | Arman
# Processing Record 59 | Betsiamites
# Processing Record 60 | Morondava
# Processing Record 61 | Busselton
# Processing Record 62 | Cidreira
# Processing Record 63 | Cape Town
# Processing Record 64 | Coahuayana
# Processing Record 65 | Mar del Plata
# Processing Record 66 | Karratha
# City not found. Skipping
# Processing Record 67 | Mataura
# City not found. Skipping
# Processing Record 68 | Mount Gambier
# Processing Record 69 | Mujiayingzi
# Processing Record 70 | Marsh Harbour
# City not found. Skipping
# Processing Record 71 | Saint-Pierre
# Processing Record 72 | Vardo
# City not found. Skipping
# Processing Record 73 | Kimbe
# City not found. Skipping
# Processing Record 74 | Yulara
# Processing Record 75 | Hambantota
# Processing Record 76 | Tuatapere
# Processing Record 77 | Lala
# Processing Record 78 | Georgetown
# Processing Record 79 | Nanortalik
# Processing Record 80 | Margate
# City not found. Skipping
# Processing Record 81 | Kapaa
# Processing Record 82 | Butaritari
# Processing Record 83 | Pevek
# City not found. Skipping
# Processing Record 84 | Saint Cloud
# Processing Record 85 | Pangnirtung
# Processing Record 86 | New Norfolk
# Processing Record 87 | Avera
# Processing Record 88 | Beyneu
# Processing Record 89 | Longyearbyen
# Processing Record 90 | Balad
# Processing Record 91 | Kiama
# Processing Record 92 | Karacakoy
# Processing Record 93 | Hay River
# Processing Record 94 | Ayr
# Processing Record 95 | Grand Gaube
# Processing Record 96 | Lerwick
# Processing Record 97 | Werda
# Processing Record 98 | Lensk
# Processing Record 99 | Edwardsville
# City not found. Skipping
# Processing Record 100 | Vostok
# Processing Record 101 | Barrow
# Processing Record 102 | Khatanga
# Processing Record 103 | Ballina
# Processing Record 104 | Mango
# Processing Record 105 | Acajutla
# Processing Record 106 | Lompoc
# Processing Record 107 | Tshikapa
# Processing Record 108 | Vestmannaeyjar
# Processing Record 109 | Mogadishu
# Processing Record 110 | Kaitangata
# Processing Record 111 | Atuona
# Processing Record 112 | Provideniya
# Processing Record 113 | Fortuna
# Processing Record 114 | Cabo San Lucas
# Processing Record 115 | Hamilton
# Processing Record 116 | Kodiak
# Processing Record 117 | Changping
# City not found. Skipping
# Processing Record 118 | Kiunga
# Processing Record 119 | Ostrovnoy
# Processing Record 120 | East London
# City not found. Skipping
# Processing Record 121 | Hilo
# Processing Record 122 | Maksatikha
# Processing Record 123 | Hobart
# City not found. Skipping
# Processing Record 124 | College
# Processing Record 125 | Upernavik
# Processing Record 126 | Port-Gentil
# Processing Record 127 | Astoria
# Processing Record 128 | Dikson
# Processing Record 129 | Port Alfred
# Processing Record 130 | Norman Wells
# Processing Record 131 | Riverton
# Processing Record 132 | Hithadhoo
# Processing Record 133 | Luau
# Processing Record 134 | Haveri
# Processing Record 135 | Axim
# Processing Record 136 | Geraldton
# Processing Record 137 | Puerto Madero
# Processing Record 138 | Omsukchan
# Processing Record 139 | Mandapam
# Processing Record 140 | Atar
# City not found. Skipping
# Processing Record 141 | Tarakan
# Processing Record 142 | Torbay
# Processing Record 143 | Castro
# Processing Record 144 | Glenwood Springs
# Processing Record 145 | Hong Gai
# Processing Record 146 | Sitka
# City not found. Skipping
# Processing Record 147 | Nueva Guinea
# City not found. Skipping
# Processing Record 148 | Bonavista
# Processing Record 149 | Sartana
# Processing Record 150 | Litovko
# Processing Record 151 | Bethanien
# Processing Record 152 | Dongsheng
# Processing Record 153 | Havelock
# Processing Record 154 | Lorengau
# Processing Record 155 | Ambulu
# Processing Record 156 | Portland
# Processing Record 157 | Safut
# Processing Record 158 | Sola
# Processing Record 159 | Rockhampton
# Processing Record 160 | Mahebourg
# Processing Record 161 | San Patricio
# Processing Record 162 | Mattoon
# Processing Record 163 | Victoria
# Processing Record 164 | Quatre Cocos
# City not found. Skipping
# Processing Record 165 | Sao Filipe
# Processing Record 166 | Chicama
# Processing Record 167 | Saint-Augustin
# Processing Record 168 | Vila Velha
# Processing Record 169 | Mount Pleasant
# Processing Record 170 | Jizan
# Processing Record 171 | Lichtenau
# Processing Record 172 | Mangrol
# City not found. Skipping
# Processing Record 173 | Boddam
# Processing Record 174 | Tomatlan
# Processing Record 175 | Teya
# Processing Record 176 | Konstantinovka
# Processing Record 177 | Comodoro Rivadavia
# Processing Record 178 | Jalu
# Processing Record 179 | Iqaluit
# Processing Record 180 | Finschhafen
# Processing Record 181 | Yerbogachen
# Processing Record 182 | Henties Bay
# Processing Record 183 | Saint-Georges
# Processing Record 184 | Acapulco
# Processing Record 185 | Chuy
# Processing Record 186 | Lavumisa
# Processing Record 187 | Kurumkan
# Processing Record 188 | Bukachacha
# Processing Record 189 | Airai
# City not found. Skipping
# Processing Record 190 | Yatou
# Processing Record 191 | Isangel
# Processing Record 192 | Luwuk
# City not found. Skipping
# Processing Record 193 | San Juan
# Processing Record 194 | Beloha
# Processing Record 195 | Carnarvon
# Processing Record 196 | Kerchevskiy
# Processing Record 197 | Carlos Barbosa
# Processing Record 198 | Kalmunai
# Processing Record 199 | Vila Franca do Campo
# Processing Record 200 | Linhares
# City not found. Skipping
# Processing Record 201 | Poplar Bluff
# Processing Record 202 | La Ronge
# Processing Record 203 | Trelew
# Processing Record 204 | Sorland
# Processing Record 205 | Lebu
# Processing Record 206 | Beringovskiy
# Processing Record 207 | Sakaiminato
# City not found. Skipping
# Processing Record 208 | Kenai
# Processing Record 209 | Pisco
# Processing Record 210 | Mbekenyera
# Processing Record 211 | Padang
# Processing Record 212 | La Libertad
# Processing Record 213 | Toora-Khem
# Processing Record 214 | Santa Isabel do Rio Negro
# Processing Record 215 | Leningradskiy
# Processing Record 216 | Praia
# Processing Record 217 | Bathsheba
# Processing Record 218 | Narsaq
# Processing Record 219 | Tiznit
# Processing Record 220 | Rexburg
# Processing Record 221 | Abbeville
# Processing Record 222 | Harper
# Processing Record 223 | Bucerias
# Processing Record 224 | Barranca
# Processing Record 225 | Bose
# Processing Record 226 | Urubicha
# City not found. Skipping
# City not found. Skipping
# Processing Record 227 | Luderitz
# Processing Record 228 | Kavaratti
# Processing Record 229 | Pangody
# Processing Record 230 | Bandar-e Lengeh
# City not found. Skipping
# Processing Record 231 | Gambo
# Processing Record 232 | Kudat
# Processing Record 233 | Bumba
# Processing Record 234 | Tiarei
# Processing Record 235 | Santa Vitoria do Palmar
# Processing Record 236 | Hirara
# Processing Record 237 | Caravelas
# Processing Record 238 | Galveston
# City not found. Skipping
# Processing Record 239 | Banda Aceh
# Processing Record 240 | Nsanje
# Processing Record 241 | Kununurra
# Processing Record 242 | Shambu
# Processing Record 243 | Sedalia
# Processing Record 244 | Yar-Sale
# Processing Record 245 | Chatellerault
# Processing Record 246 | Ilulissat
# City not found. Skipping
# Processing Record 247 | Byron Bay
# Processing Record 248 | Alofi
# City not found. Skipping
# Processing Record 249 | Constitucion
# Processing Record 250 | Qaqortoq
# Processing Record 251 | Bandarbeyla
# City not found. Skipping
# Processing Record 252 | Lugovoy
# Processing Record 253 | Fukue
# Processing Record 254 | Husavik
# Processing Record 255 | Paramonga
# Processing Record 256 | Shizuishan
# Processing Record 257 | Koungheul
# Processing Record 258 | Prince Rupert
# Processing Record 259 | Samarai
# Processing Record 260 | Uaua
# Processing Record 261 | Qaanaaq
# Processing Record 262 | Srednekolymsk
# Processing Record 263 | Chateaubelair
# City not found. Skipping
# Processing Record 264 | Petropavlovsk-Kamchatskiy
# Processing Record 265 | Rovaniemi
# Processing Record 266 | Barabai
# Processing Record 267 | Oyama
# Processing Record 268 | Maniitsoq
# Processing Record 269 | Maltahohe
# Processing Record 270 | Armacao de Pera
# Processing Record 271 | Rocha
# City not found. Skipping
# Processing Record 272 | Helong
# Processing Record 273 | Sulecin
# Processing Record 274 | Mizdah
# Processing Record 275 | Grobina
# Processing Record 276 | Saint George
# Processing Record 277 | Cabedelo
# Processing Record 278 | Skelleftea
# Processing Record 279 | Alice Springs
# Processing Record 280 | Auki
# Processing Record 281 | San Policarpo
# Processing Record 282 | Am Timan
# Processing Record 283 | Finnsnes
# Processing Record 284 | Namatanai
# Processing Record 285 | Inhambane
# Processing Record 286 | Buncrana
# Processing Record 287 | Collierville
# Processing Record 288 | Hanumangarh
# Processing Record 289 | Ternovka
# Processing Record 290 | Strezhevoy
# Processing Record 291 | Naze
# Processing Record 292 | Novobirilyussy
# Processing Record 293 | Mgachi
# Processing Record 294 | Ponta do Sol
# Processing Record 295 | Tautira
# Processing Record 296 | Bambous Virieux
# City not found. Skipping
# Processing Record 297 | Solnechnyy
# Processing Record 298 | Talnakh
# Processing Record 299 | Nchelenge
# Processing Record 300 | Talakan
# Processing Record 301 | Sur
# Processing Record 302 | Saint Anthony
# Processing Record 303 | Nagato
# Processing Record 304 | Phan Thiet
# Processing Record 305 | Kavieng
# Processing Record 306 | Broken Hill
# Processing Record 307 | Bezenchuk
# Processing Record 308 | Pacifica
# City not found. Skipping
# City not found. Skipping
# Processing Record 309 | Tasiilaq
# Processing Record 310 | Kahului
# Processing Record 311 | Sibolga
# Processing Record 312 | Bubaque
# City not found. Skipping
# Processing Record 313 | Itarema
# Processing Record 314 | Kruisfontein
# Processing Record 315 | Guiyang
# Processing Record 316 | Avarua
# Processing Record 317 | Betwagan
# Processing Record 318 | Moscow
# Processing Record 319 | Sayyan
# City not found. Skipping
# Processing Record 320 | Klaksvik
# Processing Record 321 | Okhotsk
# City not found. Skipping
# City not found. Skipping
# Processing Record 322 | Mount Isa
# City not found. Skipping
# City not found. Skipping
# Processing Record 323 | Gayeri
# Processing Record 324 | Vao
# Processing Record 325 | Lagoa
# Processing Record 326 | Stromness
# Processing Record 327 | Hohhot
# Processing Record 328 | Lata
# Processing Record 329 | Kayes
# Processing Record 330 | Faanui
# Processing Record 331 | Zhongshu
# Processing Record 332 | Kalabagh
# Processing Record 333 | Port Moresby
# Processing Record 334 | Huarmey
# Processing Record 335 | Guerrero Negro
# Processing Record 336 | Homer
# Processing Record 337 | Vysokogornyy
# Processing Record 338 | Port Blair
# Processing Record 339 | Kerema
# Processing Record 340 | Flinders
# Processing Record 341 | Kerman
# Processing Record 342 | Dingle
# Processing Record 343 | Ancud
# Processing Record 344 | Adrar
# Processing Record 345 | Santiago
# Processing Record 346 | Oranjestad
# Processing Record 347 | Tiksi
# Processing Record 348 | Inuvik
# Processing Record 349 | Taltal
# Processing Record 350 | Mogok
# Processing Record 351 | Nome
# City not found. Skipping
# Processing Record 352 | Muroto
# Processing Record 353 | Haines Junction
# Processing Record 354 | Coihaique
# Processing Record 355 | Sao Felix do Xingu
# Processing Record 356 | Salalah
# City not found. Skipping
# Processing Record 357 | Jacareacanga
# Processing Record 358 | Snasa
# Processing Record 359 | Aliwal North
# Processing Record 360 | Lagos
# Processing Record 361 | Lodwar
# Processing Record 362 | Popondetta
# Processing Record 363 | Kayerkan
# Processing Record 364 | Belmonte
# Processing Record 365 | Ahmadpur East
# Processing Record 366 | Miyako
# Processing Record 367 | Koslan
# Processing Record 368 | Yurgamysh
# Processing Record 369 | Pueblo Nuevo
# Processing Record 370 | Pokoynoye
# Processing Record 371 | Pilar
# Processing Record 372 | Krasnoborsk
# City not found. Skipping
# Processing Record 373 | Plaridel
# Processing Record 374 | Codrington
# Processing Record 375 | Kholtoson
# Processing Record 376 | Plainview
# Processing Record 377 | Port Hardy
# Processing Record 378 | Berdigestyakh
# Processing Record 379 | Ladario
# Processing Record 380 | Kasongo
# Processing Record 381 | Waingapu
# Processing Record 382 | Port Lincoln
# Processing Record 383 | Santa Margherita Ligure
# Processing Record 384 | Kungurtug
# Processing Record 385 | Pacific Grove
# Processing Record 386 | Cayenne
# City not found. Skipping
# Processing Record 387 | Siparia
# Processing Record 388 | Quang Ngai
# City not found. Skipping
# Processing Record 389 | Mawlaik
# Processing Record 390 | Birao
# Processing Record 391 | Rolla
# Processing Record 392 | Souillac
# City not found. Skipping
# Processing Record 393 | Kurilsk
# Processing Record 394 | Esperance
# Processing Record 395 | Richards Bay
# Processing Record 396 | Stoughton
# Processing Record 397 | Great Falls
# City not found. Skipping
# Processing Record 398 | Ishinomaki
# Processing Record 399 | Vanimo
# Processing Record 400 | San Francisco
# Processing Record 401 | Hofn
# Processing Record 402 | Blyth
# Processing Record 403 | Paita
# Processing Record 404 | Bealanana
# Processing Record 405 | Slave Lake
# Processing Record 406 | Kanniyakumari
# Processing Record 407 | Cotonou
# Processing Record 408 | Carauari
# Processing Record 409 | Srivardhan
# Processing Record 410 | Anshun
# Processing Record 411 | Ramshir
# City not found. Skipping
# City not found. Skipping
# Processing Record 412 | Pimentel
# Processing Record 413 | Aasiaat
# City not found. Skipping
# Processing Record 414 | Morris
# City not found. Skipping
# City not found. Skipping
# Processing Record 415 | Bilma
# Processing Record 416 | Baykit
# Processing Record 417 | Paamiut
# Processing Record 418 | Pemba
# Processing Record 419 | Araouane
# Processing Record 420 | Benjamin Aceval
# Processing Record 421 | Gat
# Processing Record 422 | Harrison
# Processing Record 423 | Tucurui
# Processing Record 424 | Bacolod
# Processing Record 425 | Zhanakorgan
# City not found. Skipping
# Processing Record 426 | Muana
# Processing Record 427 | Virginia Beach
# Processing Record 428 | Ahuimanu
# Processing Record 429 | Venustiano Carranza
# City not found. Skipping
# City not found. Skipping
# Processing Record 430 | El Alto
# Processing Record 431 | Khash
# Processing Record 432 | Cheyenne
# Processing Record 433 | Dharchula
# Processing Record 434 | Wukari
# Processing Record 435 | Aksarka
# Processing Record 436 | Klyuchi
# Processing Record 437 | Nyahururu
# Processing Record 438 | Marrakesh
# Processing Record 439 | Muros
# Processing Record 440 | Kulhudhuffushi
# City not found. Skipping
# Processing Record 441 | Ukiah
# Processing Record 442 | Egvekinot
# Processing Record 443 | Zhigansk
# Processing Record 444 | Khlevnoye
# Processing Record 445 | Muravlenko
# Processing Record 446 | Flin Flon
# Processing Record 447 | Muslyumovo
# Processing Record 448 | Shimanovsk
# Processing Record 449 | Ust-Tsilma
# Processing Record 450 | Damaturu
# Processing Record 451 | Usinsk
# Processing Record 452 | Gushikawa
# Processing Record 453 | Hasaki
# Processing Record 454 | Russell
# City not found. Skipping
# Processing Record 455 | Heihe
# Processing Record 456 | Samfya
# City not found. Skipping
# Processing Record 457 | Grande Prairie
# Processing Record 458 | Fredericksburg
# City not found. Skipping
# Processing Record 459 | Idanre
# Processing Record 460 | Adjumani
# Processing Record 461 | Hede
# Processing Record 462 | Taoudenni
# Processing Record 463 | Amahai
# Processing Record 464 | Oktyabrskoye
# Processing Record 465 | Itoman
# Processing Record 466 | Whitianga
# Processing Record 467 | Balakhta
# Processing Record 468 | Ostersund
# Processing Record 469 | Merauke
# Processing Record 470 | Basco
# Processing Record 471 | Manzil Salim
# Processing Record 472 | Sorong
# City not found. Skipping
# Processing Record 473 | Hobyo
# Processing Record 474 | Walvis Bay
# Processing Record 475 | Aklavik
# Processing Record 476 | Yeniseysk
# Processing Record 477 | Prainha
# Processing Record 478 | Feijo
# Processing Record 479 | Kichmengskiy Gorodok
# Processing Record 480 | Tsumeb
# City not found. Skipping
# Processing Record 481 | Ust-Ishim
# Processing Record 482 | Manzhouli
# Processing Record 483 | Prescott
# Processing Record 484 | Kolyshley
# Processing Record 485 | Kidal
# Processing Record 486 | Nefteyugansk
# City not found. Skipping
# City not found. Skipping
# Processing Record 487 | Registro
# Processing Record 488 | Tecoanapa
# Processing Record 489 | Chabahar
# Processing Record 490 | Behshahr
# Processing Record 491 | Brnakot
# Processing Record 492 | Rio Grande
# Processing Record 493 | Abashiri
# City not found. Skipping
# Processing Record 494 | Kuryk
# Processing Record 495 | Ewa Beach
# Processing Record 496 | Xushan
# Processing Record 497 | Urambo
# Processing Record 498 | Agua Dulce
# Processing Record 499 | Hami
# Processing Record 500 | Saryg-Sep
# City not found. Skipping
# Processing Record 501 | Bang Saphan
# Processing Record 502 | Chimoio
# City not found. Skipping
# Processing Record 503 | Seoul
# Processing Record 504 | Ayagoz
# Processing Record 505 | Maceio
# Processing Record 506 | Traralgon
# Processing Record 507 | Svencionys
# Processing Record 508 | Praia da Vitoria
# Processing Record 509 | Jertih
# Processing Record 510 | Katsuura
# Processing Record 511 | Bulls
# Processing Record 512 | Bulgan
# Processing Record 513 | Marsaxlokk
# Processing Record 514 | Katobu
# Processing Record 515 | Duluth
# Processing Record 516 | Salihorsk
# Processing Record 517 | Comonfort
# Processing Record 518 | Lanzhou
# City not found. Skipping
# Processing Record 519 | Sioux Lookout
# Processing Record 520 | Kuusamo
# Processing Record 521 | Fundao
# Processing Record 522 | Puerto Escondido
# Processing Record 523 | Clyde River
# Processing Record 524 | Outjo
# Processing Record 525 | Buluang
# Processing Record 526 | Yaring
# Processing Record 527 | Kozhva
# Processing Record 528 | Xining
# Processing Record 529 | Wajir
# Processing Record 530 | Rome
# Processing Record 531 | Coihueco
# Processing Record 532 | Soure
# Processing Record 533 | Vila do Maio
# Processing Record 534 | Opuwo
# City not found. Skipping
# City not found. Skipping
# Processing Record 535 | Gigmoto
# Processing Record 536 | Aykhal
# Processing Record 537 | Malanville
# Processing Record 538 | Oil City
# Processing Record 539 | Qarqin
# Processing Record 540 | Kampong Chhnang

# %%
weatherpy_dict = {
    "City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
}

# Create a data frame from dictionary
weather_data = pd.DataFrame(weatherpy_dict)

# Display count of weather data values 
weather_data.count()
# Out:
# City          540
# Cloudiness    540
# Country       540
# Date          540
# Humidity      540
# Lat           540
# Lng           540
# Max Temp      540
# Wind Speed    540
# dtype: int64

# %%
# Save as a csv
# Note to avoid any issues later, use encoding="utf-8"
weather_data.to_csv("weather_output.csv", encoding="utf-8", index=False)

# Display data frame head 
weather_data.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0    Punta Arenas           0      CL  1561562717        80 -53.16  -70.91
# 1  Saint-Philippe          75      CA  1561562717        61  45.36  -73.48
# 2  Ribeira Grande          40      PT  1561562718        56  38.52  -28.70
# 3      Bredasdorp           0      ZA  1561562718        77 -34.53   20.04
# 4           Bluff          22      AU  1561562719        82 -23.58  149.07
#
#    Max Temp  Wind Speed
# 0   273.150        6.70
# 1   299.820        3.10
# 2   295.150        6.70
# 3   290.370        3.60
# 4   288.197        8.46

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s=30)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (6/26/2019)")
plt.ylabel("Max. Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Max_Temp_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s=30)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (6/26/2019)")
plt.ylabel("Humidity ")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Humidity_vs_Latitude.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s=30)

# Incorporate the other graph properties
plt.title("City Latitude vs.Cloudiness (6/26/2019)")
plt.ylabel("Cloudiness ")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_Cloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s=30)

# Incorporate the other graph properties
plt.title("City Latitude vs.Wind Speed (6/26/2019)")
plt.ylabel("Wind Speed ")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("Latitude_vs_Wind Speed.png")

# Show plot
plt.show()
